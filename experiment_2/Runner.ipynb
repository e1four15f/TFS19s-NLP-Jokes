# %%
# !pip install -q textgenrnn
from textgenrnn import textgenrnn
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model_name = 'colaboratory' 

textgen = textgenrnn(weights_path=model_name + '_weights.hdf5',
                       vocab_path=model_name + '_vocab.json',
                       config_path=model_name + '_config.json')

# %%
textgen.generate(10)
# Out:
# ы вчера готовили в постель конкурса на столе.
#
# #анекдоты #юмор #смех #Ржака #Позитив"
# "— Ты снова собака и просила в третьем языке как за воду подарили против и начинаются по моим постели. В разводе красный странный вид не авто. Потом вы мне на поводу разрешить не курить с тремя мужчиной своей анкет
#
# ою соседку, пожалуйста мыслить вас посадить молодой человек просто случайно написать от анализации. Ну и ещё придумал в ней полупатки домой. На следующий день на продуктах рассчитался по пробке отвертку больше.
# - А когда он мне на стареньке вообще не вышла трубу к себе под ней. Это когда мне даже н
#
# , у меня в заднем случае на середине. Подходит к гене в соседней комнате на работу страшно, потому что просто как молодой человек не смог на сечь в мире?
# - Да нет, пожалуйста, имею ваши часа нормальные представить девочка с общем, а он отвечает:
# - Нет, почему у тебя на прошлой семье не то что у ме
#
#  это вы поставили в отпуск!
# - Ну и что?
# - Знаете ли вы очень лечить Москвич?
# - Нет, блин, не так верится. А вот вы выбрасываете про ужин?
# - А он не смогли попал."
# "- Дорогой, у меня уже с ним в одной возрасте назвал обратно.
# "Не смотри, обошения на следующий день рождения красную книгу.
# - Так все
#
#  в постели. Вовочка стали за прокуратурочку в полночь надо окружать.
# - Да, да вот вы спит себя в автомобиле.
# - Скажи мне, какие веселие банка.
# - А я сегодня сексом на кухню и вы можете справиться в простыню?
# - Да, какая разница мне нравится в 2 часа.
# - Вы знаете открыть свою жизнь и сказала сейч
#
# что такое солдаты в лесу?
# - Скажи, сегодня все позвонили в продажую за пробка и страшно, а на столе!"
# "— Ну, как ведь в компании ""Волк крупную капусту произносятого на неделю. И в половину показывался к сексом с проводимом и спрашивает:
# — Ты можешь сегодня на собеседовании кончальное телефон. Она с
#
# следний коммерческий подарок приходит к отцу и говорит:
# — А вот так много анекдотов не подошел!
# "Моя семья спрашивает мама и говорит:
# - Нет, вы мне нормальные детей отдали за рукав и подумал. На следующий день в третьем надо сидит на пробку и спрашивает у подруга, смотрит на семечке, но теперь в это
#
# а столе страшное услышать режиссированный организм
# соседка по дискому простору мне на себя без пенсионеров.
# - Ну, а вот думаю, что вы просто случайно начинаете место обмениваться в образовании машине на работе."
# "- Скажи, как откуда вы сделали в одной военкомате на дом. А теперь такая же так слыши
#
# делает мужик на простыне.
# - А козой?
# - Да, первые белай, - говорит его свет.
# - Так вот, наконец-то вы не пришли..."
# "На уроках заходит мужик в комнату, молодой человек поднимает его перед страхому.
# Вовочка:
# - Я не дала себя в полной свете!"
# "На работе сегодня подарили мужик на столику. Водитель
#
# ит к своей подруге и говорит:
# — Мой как вам на крыше на работе."
# "— Ты чего такой вот такой хорошенькая профессор, на что вы стали просто на крыше словами. Вот когда ты не знаешь, что я дам в том, что ты - подумал тебя за своей жены.
# - А на кого ты умный справишься?
# - Нет!
# - Как тебе сказали?
# -
